# %%
from __future__ import print_function, division, unicode_literals
import os.path
import pandas as pd
import numpy as np
import eeghdf
from pprint import pprint

import ipywidgets
from IPython.display import display

# import eegvis.stacklineplot
import eegvis.montageview as montageview
import eegvis.nb_eegview as nb_eegview
import eegvis.stackplot_bokeh as sbokplot
from bokeh.io import output_notebook, push_notebook
import bokeh.plotting as bplt
from bokeh.plotting import show
output_notebook()
# Out:
# C:\Users\clee\Anaconda3\envs\py36mayavi\lib\site-packages\h5py\__init__.py:36: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters
#     <div class="bk-root">
#         <a href="https://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="7910af32-7a33-4196-8c1d-8c3ae3975c0f">Loading BokehJS ...</span>
#     </div>

# %%
ARCHIVEDIR = r'../../eeg-hdfstorage/data/'
#EEGFILE = ARCHIVEDIR + 'spasms.eeghdf'
EEGFILE = ARCHIVEDIR + 'absence_epilepsy.eeghdf'

# %%
EEGFILE
# Out:
# '../../eeg-hdfstorage/data/absence_epilepsy.eeghdf'

# %%
hf = eeghdf.Eeghdf(EEGFILE)

# %%
eegbrow = nb_eegview.Eegbrowser(hf)
# Out:
# HBox(children=(Button(description='go backward 10s', style=ButtonStyle()), Button(description='go forward 10s'…
# <div class="bk-root">
#     <div class="bk-plotdiv" id="641aa616-fcc5-4e32-9fe1-3c69e7b87e96"></div>
# </div>

# %%
int_range = ipywidgets.IntSlider()
display(int_range)

def on_value_change(change):
    print(change['new'])

int_range.observe(on_value_change, names='value')
# Out:
# IntSlider(value=0)
